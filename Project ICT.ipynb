# %%
#importing packages
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
#calling dataset
HR_data=pd.read_excel(r'C:\Users\Admin\Desktop\HR dataset-team 7.xlsx')
HR_data.head()
# Out:
#     Age              Attrition BusinessTravel  DailyRate Department  \
# 0  41.0  Voluntary Resignation  Travel_Rarely     1102.0      Sales
# 1  41.0  Voluntary Resignation  Travel_Rarely     1102.0      Sales
# 2  41.0  Voluntary Resignation  Travel_Rarely     1102.0      Sales
# 3  41.0  Voluntary Resignation  Travel_Rarely     1102.0      Sales
# 4  41.0  Voluntary Resignation  Travel_Rarely     1102.0      Sales
#
#   DistanceFromHome  Education EducationField EmployeeCount EmployeeNumber  \
# 0                1        2.0  Life Sciences             1              1
# 1                1        2.0  Life Sciences             1              1
# 2                1        2.0  Life Sciences             1              7
# 3                1        2.0  Life Sciences             1              8
# 4                1        2.0  Life Sciences             1              9
#
#    ... StandardHours  StockOptionLevel TotalWorkingYears  \
# ...

# %%
#basic information about dataset
HR_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23436 entries, 0 to 23435
# Data columns (total 37 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       23433 non-null  float64
#  1   Attrition                 23423 non-null  object
#  2   BusinessTravel            23428 non-null  object
#  3   DailyRate                 23424 non-null  float64
#  4   Department                23425 non-null  object
#  5   DistanceFromHome          23427 non-null  object
#  6   Education                 23424 non-null  float64
#  7   EducationField            23427 non-null  object
#  8   EmployeeCount             23431 non-null  object
#  9   EmployeeNumber            23435 non-null  object
#  10  Application ID            23433 non-null  object
#  11  EnvironmentSatisfaction   23427 non-null  float64
#  12  Gender                    23426 non-null  object
# ...

# %%
#shape of dataset
HR_data.shape
# Out:
# (23436, 37)

# %%
#column names
HR_data.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'Application ID', 'EnvironmentSatisfaction', 'Gender',
#        'HourlyRate', 'JobInvolvement', 'JobLevel', 'JobRole',
#        'JobSatisfaction', 'MaritalStatus', 'MonthlyIncome', 'MonthlyRate',
#        'NumCompaniesWorked', 'Over18', 'OverTime', 'PercentSalaryHike',
#        'PerformanceRating', 'RelationshipSatisfaction', 'StandardHours',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager', 'Employee Source'],
#       dtype='object')

# %%
HR_data.describe()
# Out:
#                 Age     DailyRate     Education  EnvironmentSatisfaction  \
# count  23433.000000  23424.000000  23424.000000             23427.000000
# mean      36.936671    801.828765      2.910050                13.681777
# std        9.137432    403.206166      1.024931              1186.544372
# min       18.000000    102.000000      1.000000                 1.000000
# 25%       30.000000    465.000000      2.000000                 2.000000
# 50%       36.000000    802.000000      3.000000                 3.000000
# 75%       43.000000   1157.000000      4.000000                 4.000000
# max       60.000000   1499.000000      6.000000            129588.000000
#
#        JobInvolvement      JobLevel   MonthlyRate  NumCompaniesWorked  \
# count    23427.000000  23429.000000  23425.000000        23427.000000
# mean         2.733811      2.064023  14304.343821            3.887779
# std          0.836860      1.105421   7102.636293          155.332904
# ...

# %%
#checking for null values
HR_data.isna().sum()
# Out:
# Age                          3
# Attrition                   13
# BusinessTravel               8
# DailyRate                   12
# Department                  11
# DistanceFromHome             9
# Education                   12
# EducationField               9
# EmployeeCount                5
# EmployeeNumber               1
# Application ID               3
# EnvironmentSatisfaction      9
# Gender                      10
# HourlyRate                   9
# JobInvolvement               9
# JobLevel                     7
# JobRole                      9
# JobSatisfaction              9
# MaritalStatus               11
# MonthlyIncome               13
# MonthlyRate                 11
# NumCompaniesWorked           9
# Over18                      10
# OverTime                    12
# PercentSalaryHike           14
# PerformanceRating           10
# RelationshipSatisfaction     8
# StandardHours               10
# StockOptionLevel             9
# TotalWorkingYears            8
# ...

# %%
#checking for nul value percentage
Nullvalue_percentage=(HR_data.isna().sum()/len(HR_data))*100
Nullvalue_percentage
# Out:
# Age                         0.012801
# Attrition                   0.055470
# BusinessTravel              0.034136
# DailyRate                   0.051203
# Department                  0.046936
# DistanceFromHome            0.038402
# Education                   0.051203
# EducationField              0.038402
# EmployeeCount               0.021335
# EmployeeNumber              0.004267
# Application ID              0.012801
# EnvironmentSatisfaction     0.038402
# Gender                      0.042669
# HourlyRate                  0.038402
# JobInvolvement              0.038402
# JobLevel                    0.029869
# JobRole                     0.038402
# JobSatisfaction             0.038402
# MaritalStatus               0.046936
# MonthlyIncome               0.055470
# MonthlyRate                 0.046936
# NumCompaniesWorked          0.038402
# Over18                      0.042669
# OverTime                    0.051203
# PercentSalaryHike           0.059737
# ...

# %%
#checking for total null value percentage
Total_nullvalue_percentage=Nullvalue_percentage.sum()
Total_nullvalue_percentage
# Out:
# 1.5019627922853733

# %%
#checking for numerical columns
num_cols=[features for features in HR_data.columns if HR_data[features].dtypes !='O']
num_cols
# Out:
# ['Age',
#  'DailyRate',
#  'Education',
#  'EnvironmentSatisfaction',
#  'JobInvolvement',
#  'JobLevel',
#  'MonthlyRate',
#  'NumCompaniesWorked',
#  'PerformanceRating',
#  'RelationshipSatisfaction',
#  'StandardHours',
#  'StockOptionLevel',
#  'TotalWorkingYears',
#  'TrainingTimesLastYear',
#  'WorkLifeBalance',
#  'YearsAtCompany',
#  'YearsInCurrentRole',
#  'YearsSinceLastPromotion',
#  'YearsWithCurrManager']

# %%
#graph for numerical columns
HR_data.hist(figsize=(18, 14))
# Out:
# array([[<AxesSubplot:title={'center':'Age'}>,
#         <AxesSubplot:title={'center':'DailyRate'}>,
#         <AxesSubplot:title={'center':'Education'}>,
#         <AxesSubplot:title={'center':'EnvironmentSatisfaction'}>],
#        [<AxesSubplot:title={'center':'JobInvolvement'}>,
#         <AxesSubplot:title={'center':'JobLevel'}>,
#         <AxesSubplot:title={'center':'MonthlyRate'}>,
#         <AxesSubplot:title={'center':'NumCompaniesWorked'}>],
#        [<AxesSubplot:title={'center':'PerformanceRating'}>,
#         <AxesSubplot:title={'center':'RelationshipSatisfaction'}>,
#         <AxesSubplot:title={'center':'StandardHours'}>,
#         <AxesSubplot:title={'center':'StockOptionLevel'}>],
#        [<AxesSubplot:title={'center':'TotalWorkingYears'}>,
#         <AxesSubplot:title={'center':'TrainingTimesLastYear'}>,
#         <AxesSubplot:title={'center':'WorkLifeBalance'}>,
#         <AxesSubplot:title={'center':'YearsAtCompany'}>],
# ...

# %%
#outlier visualization 
HR_data.plot(kind='box',subplots=True,layout=(4,5),figsize=(15,15),title='Outlier Visualization')
plt.show()

# %%
# Enlarging the pie chart
plt.rcParams['figure.figsize'] =5,5

# Indexing labels. tolist() will convert the index to list for easy manipulation
labels = HR_data['Attrition'].value_counts().index.tolist()

# Convert value counts to list
sizes = HR_data['Attrition'].value_counts().tolist()

# As the name suggest, explode will determine how much each section is separated from each other 
explode = (0, 0.1)

# Determine colour of pie chart
colors = ['yellowgreen', 'lightcoral']

plt.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%',startangle=90, textprops={'fontsize': 14})
plt.show()

# %%
#count plot for attrition
Attrition_data= HR_data['Attrition']
ax=sns.countplot(Attrition_data,palette='husl')
for p in ax.patches:
    ax.annotate(p.get_height(), (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha = 'center', va = 'center', xytext = (0, 10), textcoords = 'offset points')
plt.show()

# %%
Travel_data= HR_data['BusinessTravel']
ax=sns.countplot(Travel_data,palette='husl')
for p in ax.patches:
    ax.annotate(p.get_height(), (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha = 'center', va = 'center', xytext = (0, 10), textcoords = 'offset points')
plt.show()

# %%
plt.figure(figsize=(17,10))

ax=sns.countplot(x='BusinessTravel',hue="Attrition", data=HR_data,palette='husl')
plt.title("Business travel wise attrition",fontweight="bold", size=20)
for p in ax.patches:
    ax.annotate(p.get_height(), (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha = 'center', va = 'center', xytext = (0, 10), textcoords = 'offset points')
plt.show()

# %%
Department_data= HR_data['Department']
ax=sns.countplot(Department_data,palette='husl')
for p in ax.patches:
    ax.annotate(p.get_height(), (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha = 'center', va = 'center', xytext = (0, 10), textcoords = 'offset points')
plt.show()

# %%
plt.figure(figsize=(17,17))

ax=sns.countplot(x='Age',hue="Attrition", data=HR_data,palette='husl')
plt.title("Age wise attrition",fontweight="bold", size=20)
for p in ax.patches:
    ax.annotate(p.get_height(), (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha = 'center', va = 'center', xytext = (0, 10), textcoords = 'offset points')
plt.show()

# %%
HR_data.groupby("Attrition")["Age"]
print(HR_data.groupby("Attrition")["Age"].value_counts())
# Out:
# Attrition              Age
# Current employee       34.0    1087
#                        35.0    1084
#                        36.0    1009
#                        38.0     914
#                        40.0     826
#                                ...
# Voluntary Resignation  48.0      32
#                        49.0      32
#                        51.0      32
#                        53.0      32
#                        38.0      31
# Name: Age, Length: 82, dtype: int64

# %%
plt.figure(figsize=(10,10))

ax=sns.countplot(x='Department',hue="Attrition", data=HR_data,palette='husl')
plt.title("Department wise attrition",fontweight="bold", size=20)
for p in ax.patches:
    ax.annotate(p.get_height(), (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha = 'center', va = 'center', xytext = (0, 10), textcoords = 'offset points')
plt.show()

# %%
Distance_data= HR_data['DistanceFromHome']
ax=sns.countplot(Distance_data,palette='husl')
for p in ax.patches:
    ax.annotate(p.get_height(), (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha = 'center', va = 'center', xytext = (0, 10), textcoords = 'offset points')
plt.show()

# %%
HR_data.DistanceFromHome.value_counts()
# Out:
# 2                         3351
# 1                         3335
# 10                        1371
# 3                         1358
# 9                         1337
# 7                         1336
# 8                         1277
# 5                         1036
# 4                         1025
# 6                          948
# 16                         503
# 11                         464
# 24                         432
# 29                         430
# 23                         430
# 18                         421
# 15                         419
# 26                         400
# 25                         398
# 20                         378
# 28                         364
# 19                         352
# 14                         335
# 12                         331
# 22                         306
# 13                         304
# 17                         302
# 21                         289
# 27                         194
# Research & Development       1
# ...

# %%
HR_data.groupby("Attrition")["DistanceFromHome"]
print(HR_data.groupby("Attrition")["DistanceFromHome"].value_counts())
# Out:
# Attrition              DistanceFromHome
# Current employee       1                         2904
#                        2                         2903
#                        10                        1211
#                        7                         1160
#                        3                         1131
#                        8                         1116
#                        9                         1065
#                        4                          879
#                        5                          878
#                        6                          832
#                        16                         405
#                        11                         401
#                        18                         357
#                        26                         351
#                        23                         350
#                        29                         350
#                        15                         340
# ...

# %%
plt.figure(figsize=[10,10])
sns.countplot(x='DistanceFromHome',hue='Attrition',data=HR_data)
plt.show()

# %%
education_data= HR_data['Education']
ax=sns.countplot(education_data,palette='husl')
for p in ax.patches:
    ax.annotate(p.get_height(), (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha = 'center', va = 'center', xytext = (0, 10), textcoords = 'offset points')
plt.show()

# %%
plt.figure(figsize=(10,10))

ax=sns.countplot(x='Education',hue="Attrition", data=HR_data,palette='husl')
plt.title("Education wise attrition",fontweight="bold", size=20)
for p in ax.patches:
    ax.annotate(p.get_height(), (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha = 'center', va = 'center', xytext = (0, 10), textcoords = 'offset points')
plt.show()

# %%
Field_data= HR_data['EducationField']
ax=sns.countplot(Field_data,palette='husl')
for p in ax.patches:
    ax.annotate(p.get_height(), (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha = 'center', va = 'center', xytext = (0, 10), textcoords = 'offset points')
plt.show()

# %%
plt.figure(figsize=(17,10))

ax=sns.countplot(x='EducationField',hue="Attrition", data=HR_data,palette='husl')
plt.title("Education field wise attrition",fontweight="bold", size=20)
for p in ax.patches:
    ax.annotate(p.get_height(), (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha = 'center', va = 'center', xytext = (0, 10), textcoords = 'offset points')
plt.show()

# %%
plt.figure(figsize=(10,10))

ax=sns.countplot(x='EmployeeCount',hue="Attrition", data=HR_data,palette='husl')
plt.title("Employee count wise attrition",fontweight="bold", size=20)
for p in ax.patches:
    ax.annotate(p.get_height(), (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha = 'center', va = 'center', xytext = (0, 10), textcoords = 'offset points')
plt.show()

# %%
envsat_data= HR_data['EnvironmentSatisfaction']
ax=sns.countplot(envsat_data,palette='husl')
for p in ax.patches:
    ax.annotate(p.get_height(), (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha = 'center', va = 'center', xytext = (0, 10), textcoords = 'offset points')
plt.show()

# %%
plt.figure(figsize=(10,10))

ax=sns.countplot(x='EnvironmentSatisfaction',hue="Attrition", data=HR_data,palette='husl')
plt.title("Environment satisfaction field wise attrition",fontweight="bold", size=20)
for p in ax.patches:
    ax.annotate(p.get_height(), (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha = 'center', va = 'center', xytext = (0, 10), textcoords = 'offset points')
plt.show()

# %%
gender_data= HR_data['Gender']
ax=sns.countplot(gender_data,palette='husl')
for p in ax.patches:
    ax.annotate(p.get_height(), (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha = 'center', va = 'center', xytext = (0, 10), textcoords = 'offset points')
plt.show()

# %%
plt.figure(figsize=(10,10))

ax=sns.countplot(x='Gender',hue="Attrition", data=HR_data,palette='husl')
plt.title("Gender wise attrition",fontweight="bold", size=20)
for p in ax.patches:
    ax.annotate(p.get_height(), (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha = 'center', va = 'center', xytext = (0, 10), textcoords = 'offset points')
plt.show()

# %%
HR_data.HourlyRate.value_counts()
# Out:
# 66        480
# 98        447
# 48        447
# 42        445
# 84        444
#          ...
# 53        219
# 38        207
# 34        192
# Male        1
# Female      1
# Name: HourlyRate, Length: 73, dtype: int64

# %%
HR_data.groupby("Attrition")["HourlyRate"]
print(HR_data.groupby("Attrition")["HourlyRate"].value_counts())
# Out:
# Attrition              HourlyRate
# Current employee       42            421
#                        87            383
#                        98            383
#                        84            380
#                        96            364
#                                     ...
# Voluntary Resignation  90             24
#                        91             23
#                        59             17
#                        35             16
#                        75             16
# Name: HourlyRate, Length: 144, dtype: int64

# %%
plt.figure(figsize=[17,17])
sns.countplot(x='HourlyRate',hue='Attrition',data=HR_data)
plt.show()

# %%
involvement_data= HR_data['JobInvolvement']
ax=sns.countplot(involvement_data,palette='husl')
for p in ax.patches:
    ax.annotate(p.get_height(), (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha = 'center', va = 'center', xytext = (0, 10), textcoords = 'offset points')
plt.show()

# %%
plt.figure(figsize=(10,10))

ax=sns.countplot(x='JobInvolvement',hue="Attrition", data=HR_data,palette='husl')
plt.title("Job involvement wise attrition",fontweight="bold", size=20)
for p in ax.patches:
    ax.annotate(p.get_height(), (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha = 'center', va = 'center', xytext = (0, 10), textcoords = 'offset points')
plt.show()

# %%
plt.figure(figsize=(10,10))

ax=sns.countplot(x='JobLevel',hue="Attrition", data=HR_data,palette='husl')
plt.title("Job level wise attrition",fontweight="bold", size=20)
for p in ax.patches:
    ax.annotate(p.get_height(), (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha = 'center', va = 'center', xytext = (0, 10), textcoords = 'offset points')
plt.show()

# %%
HR_data.JobRole.value_counts()
# Out:
# Sales Executive              5111
# Research Scientist           4634
# Laboratory Technician        4162
# Manufacturing Director       2376
# Healthcare Representative    2104
# Manager                      1600
# Sales Representative         1306
# Research Director            1287
# Human Resources               845
# 5                               1
# 4                               1
# Name: JobRole, dtype: int64

# %%
role_data= HR_data['JobRole']
ax=sns.countplot(role_data,palette='husl')
for p in ax.patches:
    ax.annotate(p.get_height(), (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha = 'center', va = 'center', xytext = (0, 10), textcoords = 'offset points')
plt.show()

# %%
plt.figure(figsize=(25,10))

ax=sns.countplot(x='JobRole',hue="Attrition", data=HR_data,palette='husl')
plt.title("Job role wise attrition",fontweight="bold", size=20)
for p in ax.patches:
    ax.annotate(p.get_height(), (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha = 'center', va = 'center', xytext = (0, 10), textcoords = 'offset points')
plt.show()

# %%
jobsat_data= HR_data['JobSatisfaction']
ax=sns.countplot(jobsat_data,palette='husl')
for p in ax.patches:
    ax.annotate(p.get_height(), (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha = 'center', va = 'center', xytext = (0, 10), textcoords = 'offset points')
plt.show()

# %%
plt.figure(figsize=(10,10))

ax=sns.countplot(x='JobSatisfaction',hue="Attrition", data=HR_data,palette='husl')
plt.title("Job satisfaction wise attrition",fontweight="bold", size=20)
for p in ax.patches:
    ax.annotate(p.get_height(), (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha = 'center', va = 'center', xytext = (0, 10), textcoords = 'offset points')
plt.show()

# %%
marital_data= HR_data['MaritalStatus']
ax=sns.countplot(marital_data,palette='husl')
for p in ax.patches:
    ax.annotate(p.get_height(), (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha = 'center', va = 'center', xytext = (0, 10), textcoords = 'offset points')
plt.show()

# %%
plt.figure(figsize=(10,10))

ax=sns.countplot(x='MaritalStatus',hue="Attrition", data=HR_data,palette='husl')
plt.title("Marital status wise attrition",fontweight="bold", size=20)
for p in ax.patches:
    ax.annotate(p.get_height(), (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha = 'center', va = 'center', xytext = (0, 10), textcoords = 'offset points')
plt.show()

# %%
comwrk_data= HR_data['NumCompaniesWorked']
ax=sns.countplot(comwrk_data,palette='husl')
for p in ax.patches:
    ax.annotate(p.get_height(), (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha = 'center', va = 'center', xytext = (0, 10), textcoords = 'offset points')
plt.show()

# %%
plt.figure(figsize=(10,10))

ax=sns.countplot(x='NumCompaniesWorked',hue="Attrition", data=HR_data,palette='husl')
plt.title("Number of companies worked wise attrition",fontweight="bold", size=20)
for p in ax.patches:
    ax.annotate(p.get_height(), (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha = 'center', va = 'center', xytext = (0, 10), textcoords = 'offset points')
plt.show()

# %%
plt.figure(figsize=(10,10))

ax=sns.countplot(x='Over18',hue="Attrition", data=HR_data,palette='husl')
plt.title("Over18 wise attrition",fontweight="bold", size=20)
for p in ax.patches:
    ax.annotate(p.get_height(), (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha = 'center', va = 'center', xytext = (0, 10), textcoords = 'offset points')
plt.show()

# %%
plt.figure(figsize=(10,10))

ax=sns.countplot(x='OverTime',hue="Attrition", data=HR_data,palette='husl')
plt.title("Over time wise attrition",fontweight="bold", size=20)
for p in ax.patches:
    ax.annotate(p.get_height(), (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha = 'center', va = 'center', xytext = (0, 10), textcoords = 'offset points')
plt.show()

# %%
percenthike_data= HR_data['PercentSalaryHike']
ax=sns.countplot(percenthike_data,palette='husl')
for p in ax.patches:
    ax.annotate(p.get_height(), (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha = 'center', va = 'center', xytext = (0, 10), textcoords = 'offset points')
plt.show()

# %%
plt.figure(figsize=(10,10))

ax=sns.countplot(x='PercentSalaryHike',hue="Attrition", data=HR_data,palette='husl')
plt.title("Salary hike percentage wise attrition",fontweight="bold", size=20)
for p in ax.patches:
    ax.annotate(p.get_height(), (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha = 'center', va = 'center', xytext = (0, 10), textcoords = 'offset points')
plt.show()

# %%
performance_data= HR_data['PerformanceRating']
ax=sns.countplot(performance_data,palette='husl')
for p in ax.patches:
    ax.annotate(p.get_height(), (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha = 'center', va = 'center', xytext = (0, 10), textcoords = 'offset points')
plt.show()

# %%
plt.figure(figsize=(10,10))

ax=sns.countplot(x='PerformanceRating',hue="Attrition", data=HR_data,palette='husl')
plt.title("Performance rating wise attrition",fontweight="bold", size=20)
for p in ax.patches:
    ax.annotate(p.get_height(), (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha = 'center', va = 'center', xytext = (0, 10), textcoords = 'offset points')
plt.show()

# %%
relation_data= HR_data['RelationshipSatisfaction']
ax=sns.countplot(relation_data,palette='husl')
for p in ax.patches:
    ax.annotate(p.get_height(), (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha = 'center', va = 'center', xytext = (0, 10), textcoords = 'offset points')
plt.show()

# %%
plt.figure(figsize=(10,10))

ax=sns.countplot(x='RelationshipSatisfaction',hue="Attrition", data=HR_data,palette='husl')
plt.title("Relationship satisfaction wise attrition",fontweight="bold", size=20)
for p in ax.patches:
    ax.annotate(p.get_height(), (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha = 'center', va = 'center', xytext = (0, 10), textcoords = 'offset points')
plt.show()

# %%
plt.figure(figsize=(10,10))

ax=sns.countplot(x='StandardHours',hue="Attrition", data=HR_data,palette='husl')
plt.title("Standard hours wise attrition",fontweight="bold", size=20)
for p in ax.patches:
    ax.annotate(p.get_height(), (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha = 'center', va = 'center', xytext = (0, 10), textcoords = 'offset points')
plt.show()

# %%
stock_data= HR_data['StockOptionLevel']
ax=sns.countplot(stock_data,palette='husl')
for p in ax.patches:
    ax.annotate(p.get_height(), (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha = 'center', va = 'center', xytext = (0, 10), textcoords = 'offset points')
plt.show()

# %%
plt.figure(figsize=(10,10))

ax=sns.countplot(x='StockOptionLevel',hue="Attrition", data=HR_data,palette='husl')
plt.title("Stock option level wise attrition",fontweight="bold", size=20)
for p in ax.patches:
    ax.annotate(p.get_height(), (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha = 'center', va = 'center', xytext = (0, 10), textcoords = 'offset points')
plt.show()

# %%
plt.figure(figsize=(17,17))

ax=sns.countplot(x='TotalWorkingYears',hue="Attrition", data=HR_data,palette='husl')
plt.title("Total working years wise attrition",fontweight="bold", size=20)
for p in ax.patches:
    ax.annotate(p.get_height(), (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha = 'center', va = 'center', xytext = (0, 10), textcoords = 'offset points')
plt.show()

# %%
training_data= HR_data['TrainingTimesLastYear']
ax=sns.countplot(training_data,palette='husl')
for p in ax.patches:
    ax.annotate(p.get_height(), (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha = 'center', va = 'center', xytext = (0, 10), textcoords = 'offset points')
plt.show()

# %%
plt.figure(figsize=(10,10))

ax=sns.countplot(x='TrainingTimesLastYear',hue="Attrition", data=HR_data,palette='husl')
plt.title("Training time wise attrition",fontweight="bold", size=20)
for p in ax.patches:
    ax.annotate(p.get_height(), (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha = 'center', va = 'center', xytext = (0, 10), textcoords = 'offset points')
plt.show()

# %%
bal_data= HR_data['WorkLifeBalance']
ax=sns.countplot(bal_data,palette='husl')
for p in ax.patches:
    ax.annotate(p.get_height(), (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha = 'center', va = 'center', xytext = (0, 10), textcoords = 'offset points')
plt.show()

# %%
plt.figure(figsize=(10,10))

ax=sns.countplot(x='WorkLifeBalance',hue="Attrition", data=HR_data,palette='husl')
plt.title("work life balance wise attrition",fontweight="bold", size=20)
for p in ax.patches:
    ax.annotate(p.get_height(), (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha = 'center', va = 'center', xytext = (0, 10), textcoords = 'offset points')
plt.show()

# %%
years_data= HR_data['YearsAtCompany']
ax=sns.countplot(years_data,palette='husl')
for p in ax.patches:
    ax.annotate(p.get_height(), (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha = 'center', va = 'center', xytext = (0, 10), textcoords = 'offset points')
plt.show()

# %%
plt.figure(figsize=(17,17))

ax=sns.countplot(x='YearsAtCompany',hue="Attrition", data=HR_data,palette='husl')
plt.title("Years at company wise attrition",fontweight="bold", size=20)
for p in ax.patches:
    ax.annotate(p.get_height(), (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha = 'center', va = 'center', xytext = (0, 10), textcoords = 'offset points')
plt.show()

# %%
current_role_data= HR_data['YearsInCurrentRole']
ax=sns.countplot(current_role_data,palette='husl')
for p in ax.patches:
    ax.annotate(p.get_height(), (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha = 'center', va = 'center', xytext = (0, 10), textcoords = 'offset points')
plt.show()

# %%
plt.figure(figsize=(17,17))

ax=sns.countplot(x='YearsInCurrentRole',hue="Attrition", data=HR_data,palette='husl')
plt.title("Years in current role wise attrition",fontweight="bold", size=20)
for p in ax.patches:
    ax.annotate(p.get_height(), (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha = 'center', va = 'center', xytext = (0, 10), textcoords = 'offset points')
plt.show()

# %%
promotion_data= HR_data['YearsSinceLastPromotion']
ax=sns.countplot(promotion_data,palette='husl')
for p in ax.patches:
    ax.annotate(p.get_height(), (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha = 'center', va = 'center', xytext = (0, 10), textcoords = 'offset points')
plt.show()

# %%
plt.figure(figsize=(17,17))

ax=sns.countplot(x='YearsSinceLastPromotion',hue="Attrition", data=HR_data,palette='husl')
plt.title("Years since last promotion wise attrition",fontweight="bold", size=20)
for p in ax.patches:
    ax.annotate(p.get_height(), (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha = 'center', va = 'center', xytext = (0, 10), textcoords = 'offset points')
plt.show()

# %%
currentmanager_data= HR_data['YearsWithCurrManager']
ax=sns.countplot(currentmanager_data,palette='husl')
for p in ax.patches:
    ax.annotate(p.get_height(), (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha = 'center', va = 'center', xytext = (0, 10), textcoords = 'offset points')
plt.show()

# %%
plt.figure(figsize=(17,17))

ax=sns.countplot(x='YearsWithCurrManager',hue="Attrition", data=HR_data,palette='husl')
plt.title("Years with current manager wise attrition",fontweight="bold", size=20)
for p in ax.patches:
    ax.annotate(p.get_height(), (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha = 'center', va = 'center', xytext = (0, 10), textcoords = 'offset points')
plt.show()

# %%
source_data= HR_data['Employee Source']
ax=sns.countplot(source_data,palette='husl')
for p in ax.patches:
    ax.annotate(p.get_height(), (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha = 'center', va = 'center', xytext = (0, 10), textcoords = 'offset points')
plt.show()

# %%
plt.figure(figsize=(17,17))

ax=sns.countplot(x='Employee Source',hue="Attrition", data=HR_data,palette='husl')
plt.title("Employee source wise attrition",fontweight="bold", size=20)
for p in ax.patches:
    ax.annotate(p.get_height(), (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha = 'center', va = 'center', xytext = (0, 10), textcoords = 'offset points')
plt.show()
